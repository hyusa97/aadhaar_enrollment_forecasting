# %% [markdown]
# ##data extraction for review

# %%
import pandas as pd
df1 = pd.read_csv(r'C:\Users\hp\Desktop\4th sem\AI_Training\Projects\Udaai_adhaar\data\raw\api_data_aadhar_biometric_0_500000.csv')
df1.head()
# Out:
#          date              state      district  pincode  bio_age_5_17  \
# 0  01-03-2025            Haryana  Mahendragarh   123029           280
# 1  01-03-2025              Bihar     Madhepura   852121           144
# 2  01-03-2025  Jammu and Kashmir         Punch   185101           643
# 3  01-03-2025              Bihar       Bhojpur   802158           256
# 4  01-03-2025         Tamil Nadu       Madurai   625514           271
#
#    bio_age_17_
# 0          577
# 1          369
# 2         1091
# 3          980
# 4          815

# %%
df1.groupby('district')['date'].nunique().describe()
# Out:
# count    945.000000
# mean      21.940741
# std        5.187244
# min        1.000000
# 25%       23.000000
# 50%       24.000000
# 75%       24.000000
# max       24.000000
# Name: date, dtype: float64

# %%
# Set display to show all rows
pd.set_option('display.max_rows', None)

# Run your command
print(df1['district'].value_counts().sort_values())

# Reset to default later if needed (optional)
pd.reset_option('display.max_rows')
# Out:
# district
# Domjur                                1
# Tiswadi                               1
# Bijapur(KAR)                          1
# KOLKATA                               1
# udhampur                              1
# East midnapore                        1
# Bally Jagachha                        1
# West Medinipur                        1
# nadia                                 1
# Hooghiy                               1
# Bagpat                                1
# Bengaluru Rural                       1
# Nicobars                              1
# NADIA                                 1
# Mahoba *                              1
# East Midnapur                         1
# BALANGIR                              1
# Namchi                                2
# Tuticorin                             2
# Leh (ladakh)                          2
# South DumDum(M)                       2
# Hingoli *                             2
# Burdwan                               2
# ...

# %%
# Set display to show all rows
pd.set_option('display.max_rows', None)

# Run your command
print(df1['state'].value_counts().sort_values())

# Reset to default later if needed (optional)
pd.reset_option('display.max_rows')
# Out:
# state
# Chhatisgarh                                     1
# Uttaranchal                                     1
# west Bengal                                     1
# WESTBENGAL                                      1
# West  Bengal                                    4
# West bengal                                     5
# Westbengal                                      6
# odisha                                          6
# ODISHA                                          9
# andhra pradesh                                 11
# WEST BENGAL                                    13
# West Bangal                                    15
# Dadra & Nagar Haveli                           26
# Daman & Diu                                    70
# Jammu & Kashmir                                74
# Dadra and Nagar Haveli and Daman and Diu       75
# Dadra and Nagar Haveli                         94
# Daman and Diu                                 123
# Andaman & Nicobar Islands                     137
# ...

# %%
# 1. Set display to show everything
pd.set_option('display.max_rows', None)

# 2. Filter for UP and count the districts
# Adding .sort_index() or .sort_values() makes it much easier to read!
up_districts = df1[df1['state'] == "Uttar Pradesh"]['district'].value_counts()
print(up_districts)

# 3. Reset to default (60 rows) so you don't accidental flood your screen later
pd.reset_option('display.max_rows')
# Out:
# district
# Lucknow                       1142
# Jaunpur                       1133
# Azamgarh                      1100
# Kanpur Nagar                  1021
# Allahabad                      993
# Rae Bareli                     980
# Gorakhpur                      957
# Ghazipur                       954
# Ballia                         888
# Pratapgarh                     887
# Faizabad                       877
# Bulandshahr                    852
# Varanasi                       836
# Bara Banki                     833
# Amethi                         814
# Aligarh                        805
# Gonda                          759
# Sultanpur                      698
# Ambedkar Nagar                 692
# Ghaziabad                      683
# Prayagraj                      676
# Agra                           667
# Deoria                         653
# Bijnor                         643
# Mathura                        621
# Kheri                          616
# ...

# %%
import pandas as pd
df12 = pd.read_csv(r"C:\Users\hp\Desktop\4th sem\AI_Training\Projects\Udaai_adhaar\data\raw\test_data_new.csv")
df12.head()
# Out:
#        date              state      district  pincode  bio_age_5_17  \
# 0  1/3/2025            Haryana  Mahendragarh   123029           280
# 1  1/3/2025              Bihar     Madhepura   852121           144
# 2  1/3/2025  Jammu and Kashmir         Punch   185101           643
# 3  1/3/2025              Bihar       Bhojpur   802158           256
# 4  1/3/2025         Tamil Nadu       Madurai   625514           271
#
#    bio_age_17_
# 0          577
# 1          369
# 2         1091
# 3          980
# 4          815

# %%
pd.set_option('display.max_rows', None)

unique_dates = (
    df12['date']
    .sort_values()
    .unique()
)

for d in unique_dates:
    print(d)

pd.reset_option('display.max_rows')
# Out:
# 1/3/2025
# 1/4/2025
# 1/5/2025
# 1/6/2025
# 1/7/2025
# 1/9/2025
# 10/9/2025
# 11/9/2025
# 12/9/2025
# 13-09-2025
# 14-09-2025
# 15-09-2025
# 16-09-2025
# 17-09-2025
# 18-09-2025
# 19-09-2025
# 2/9/2025
# 3/9/2025
# 4/9/2025
# 5/9/2025
# 6/9/2025
# 7/9/2025
# 8/9/2025
# 9/9/2025

# %%
import pandas as pd
df_final = pd.read_excel(r"C:\Users\hp\Desktop\4th sem\AI_Training\Projects\Udaai_adhaar\data\upload\test_cleaned_final.xlsx")
df_final.head()
# Out:
#         date              state      district  pincode  bio_age_5_17  \
# 0 2025-01-03            Haryana  mahendragarh   123029           280
# 1 2025-01-03              Bihar     madhepura   852121           144
# 2 2025-01-03  Jammu And Kashmir         punch   185101           643
# 3 2025-01-03              Bihar       bhojpur   802158           256
# 4 2025-01-03         Tamil Nadu       madurai   625514           271
#
#    bio_age_17_
# 0          577
# 1          369
# 2         1091
# 3          980
# 4          815

# %%
import os
os.path.getsize(r"C:\Users\hp\Desktop\4th sem\AI_Training\Projects\Udaai_adhaar\data\upload\test_cleaned_final.xlsx") / (1024*1024)
# Out:
# 14.532034873962402

# %%
df_final = df_final.drop(columns=['pincode'])

# %%
df_final['total_enrollment'] = df_final['bio_age_5_17'] + df_final['bio_age_17_']

# %%
df_final = df_final.drop(columns=['bio_age_5_17', 'bio_age_17_'])
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 4 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   date              500000 non-null  datetime64[ns]
#  1   state             500000 non-null  object
#  2   district          500000 non-null  object
#  3   total_enrollment  500000 non-null  int64
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 15.3+ MB

# %%
df_final = df_final.sort_values(by=['district', 'date']).reset_index(drop=True)
df_final.head()
# Out:
#         date      state  district  total_enrollment
# 0 2025-01-03  Telangana  adilabad               119
# 1 2025-01-03  Telangana  adilabad               266
# 2 2025-01-03  Telangana  adilabad                41
# 3 2025-01-03  Telangana  adilabad                41
# 4 2025-01-03  Telangana  adilabad               143

# %%
df_final = df_final.groupby(['district', 'state', 'date'])['total_enrollment'].sum().reset_index()
df_final.head()
# Out:
#    district      state       date  total_enrollment
# 0  adilabad  Telangana 2025-01-03             12872
# 1  adilabad  Telangana 2025-01-04              9333
# 2  adilabad  Telangana 2025-01-05             10412
# 3  adilabad  Telangana 2025-01-06             14734
# 4  adilabad  Telangana 2025-01-07             17026

# %%
df_final.to_csv(r"C:\Users\hp\Desktop\4th sem\AI_Training\Projects\Udaai_adhaar\data\upload\test_cleaned_final.csv", index=False)
